# %% [markdown]
# # Exploratory Data Analysis
#
# ## Business Questions
#
# 1. What is the total revenue?
# 2. Which countries generate the most revenue?
# 3. Which product categories perform best?
# 4. What are the monthly sales trends?
# 5. Which customer segments spend the most?
# 6. What is the return rate?
# 7. Which payment methods are most used?
# 8. What factors influence profit margin?

# %%
df.shape
# Out:
# (1000123, 62)

# %%
df.head(5)
# Out:
#     order_id                  order_date  order_year  order_month  order_day  \
# 0  ORD-XAJI0  2024-10-14 11:20:05.496679        2024           10         14
# 1  ORD-NHJ7X  2024-10-21 00:49:44.681065        2024           10         21
# 2  ORD-YTJXE  2025-03-17 19:49:36.983317        2025            3         17
# 3  ORD-EIMVI  2024-09-27 06:24:44.913768        2024            9         27
# 4  ORD-OR56F  2025-05-21 17:10:48.401882        2025            5         21
#
#    order_hour  order_minute  order_second is_weekend order_status  ...  \
# 0          11            20             5         No    Completed  ...
# 1           0            49            44         No    Completed  ...
# 2          19            49            36         No    Completed  ...
# 3           6            24            44         No    Completed  ...
# 4          17            10            48         No    Completed  ...
#
#   campaign_source device_type traffic_source session_duration_minutes  \
# ...

# %%
df.describe()
# Out:
#          order_year   order_month     order_day    order_hour  order_minute  \
# count  1.000123e+06  1.000123e+06  1.000123e+06  1.000123e+06  1.000123e+06
# mean   2.024590e+03  6.514849e+00  1.575253e+01  1.148814e+01  2.949467e+01
# std    5.758891e-01  3.448711e+00  8.799790e+00  6.918078e+00  1.730984e+01
# min    2.024000e+03  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.024000e+03  4.000000e+00  8.000000e+00  5.000000e+00  1.400000e+01
# 50%    2.025000e+03  7.000000e+00  1.600000e+01  1.100000e+01  3.000000e+01
# 75%    2.025000e+03  1.000000e+01  2.300000e+01  1.700000e+01  4.400000e+01
# max    2.026000e+03  1.200000e+01  3.100000e+01  2.300000e+01  5.900000e+01
#
#        order_second           age  customer_loyalty_score  \
# count  1.000123e+06  1.000123e+06            1.000123e+06
# mean   2.948548e+01  4.649414e+01            4.997252e+01
# std    1.732781e+01  1.673373e+01            2.889377e+01
# ...

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'order_date',
#  'order_year',
#  'order_month',
#  'order_day',
#  'order_hour',
#  'order_minute',
#  'order_second',
#  'is_weekend',
#  'order_status',
#  'return_reason',
#  'customer_id',
#  'customer_name',
#  'gender',
#  'age',
#  'customer_segment',
#  'country',
#  'city',
#  'customer_loyalty_score',
#  'total_orders_by_customer',
#  'account_creation_date',
#  'product_id',
#  'product_name',
#  'category',
#  'sub_category',
#  'brand',
#  'product_rating_avg',
#  'product_reviews_count',
#  'stock_quantity',
#  'unit_price_usd',
#  'quantity',
#  'discount_percent',
#  'discount_amount_usd',
#  'total_price_usd',
#  'cost_usd',
#  'profit_usd',
#  'tax_usd',
#  'currency',
#  'payment_method',
#  'payment_status',
#  'installment_plan',
#  'shipping_method',
#  'shipping_cost_usd',
#  'delivery_days',
#  'shipping_country',
#  'warehouse_location',
#  'delivery_status',
#  'rating',
#  'review_sentiment',
#  'customer_feedback',
#  'coupon_used',
# ...

# %%
country_sales = (
    df.groupby("country")["total_price_usd"]
      .sum()
      .sort_values(ascending=False)
)

country_sales.head(10)
# Out:
# country
# Netherlands       40545046.49
# Italy             40476034.00
# Belgium           40416679.92
# Spain             40377289.51
# United Kingdom    40340497.42
# Australia         40331338.92
# United States     40236698.60
# France            40230415.60
# Canada            40202793.18
# Germany           40129063.36
# Name: total_price_usd, dtype: float64

# %%
import matplotlib.pyplot as plt

country_sales.head(10).plot( kind="bar")
plt.title("Monthly Revenue Trend")

plt.title("Top 10 Countries by Revenue")
plt.show()

# %%
#product category analysis
[col for col in df.columns if "category" in col.lower()]
# Out:
# ['category', 'sub_category']

# %%
df.groupby("category")["total_price_usd"] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# category
# Electronics    1.398660e+08
# Home           8.782868e+07
# Sports         7.291747e+07
# Health         5.746793e+07
# Clothing       4.520580e+07
# Name: total_price_usd, dtype: float64

# %%
#Find monthly revenue trend
df["order_date"] = pd.to_datetime(df["order_date"])

# %%
monthly_sales = (
    df.groupby(df["order_date"].dt.to_period("M"))
      ["total_price_usd"]
      .sum()
)

# %%
#Plot

# %%
monthly_sales.plot(figsize=(12,5))
plt.title("Monthly Revenue Trend")
plt.show()
